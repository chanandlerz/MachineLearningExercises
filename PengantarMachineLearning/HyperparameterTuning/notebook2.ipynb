# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import time
# Mengunduh dataset California Housing
X, y = fetch_california_housing(return_X_y=True)
    
# Membagi dataset menjadi training set dan testing set (70% training, 30% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    
# Melakukan scaling pada data (penting untuk regresi)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
    
print("Shape of training data:", X_train.shape)
print("Shape of testing data:", X_test.shape)
# Out:
# Shape of training data: (14448, 8)
# Shape of testing data: (6192, 8)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
    
# Inisialisasi model Random Forest Regressor
rf = RandomForestRegressor(random_state=42)
rf.fit(X_train, y_train)
    
# Evaluasi awal model tanpa tuning
y_pred = rf.predict(X_test)
initial_mse = mean_squared_error(y_test, y_pred)
print(f"Initial MSE on test set (without tuning): {initial_mse:.2f}")
# Out:
# Initial MSE on test set (without tuning): 0.26

# %%
from sklearn.model_selection import GridSearchCV
    
start_time = time.time()  # Mencatat waktu mulai
    
# Definisikan parameter grid untuk Grid Search
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}
    
# Inisialisasi GridSearchCV
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)
    
# Output hasil terbaik
print(f"Best parameters (Grid Search): {grid_search.best_params_}")
best_rf_grid = grid_search.best_estimator_
    
# Evaluasi performa model setelah Grid Search
y_pred_grid = best_rf_grid.predict(X_test)
grid_search_mse = mean_squared_error(y_test, y_pred_grid)
print(f"MSE after Grid Search: {grid_search_mse:.2f}")
end_time = time.time()  # Mencatat waktu selesai
execution_time = end_time - start_time  # Menghitung selisih waktu
print(f"Waktu eksekusi: {execution_time:.4f} detik")
# Out:
# Fitting 3 folds for each of 162 candidates, totalling 486 fits
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   8.8s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   8.7s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   9.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  17.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  19.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  19.6s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  25.6s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   7.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   7.4s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   9.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  33.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  34.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  18.6s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  22.6s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  17.6s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   8.4s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  14.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  32.4s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  33.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  34.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  10.6s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  16.7s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  16.7s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  21.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  33.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  26.7s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  27.8s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  10.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  11.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  21.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  19.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  20.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  11.7s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  31.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   8.9s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   7.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  28.9s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  30.8s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  16.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  22.4s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  25.8s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  29.7s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  10.8s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   9.4s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  10.6s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  37.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  34.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  21.9s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  18.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  17.9s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  13.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  35.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   9.6s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  31.4s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   7.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  29.7s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  18.4s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  24.6s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  23.9s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  29.4s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   9.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   7.7s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  26.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   8.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  24.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  15.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  17.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  16.6s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   8.6s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  26.9s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   8.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  28.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   8.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  26.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  18.7s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  17.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  18.4s
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/nadia/.local/share/virtualenvs/HyperparameterTuning-m-J5oo4j/lib/python3.12/site-packages/joblib/externals/loky/backend/queues.py", line 159, in _feed
#     obj_ = dumps(obj, reducers=reducers)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/nadia/.local/share/virtualenvs/HyperparameterTuning-m-J5oo4j/lib/python3.12/site-packages/joblib/externals/loky/backend/reduction.py", line 215, in dumps
#     dump(obj, buf, reducers=reducers, protocol=protocol)
#   File "/home/nadia/.local/share/virtualenvs/HyperparameterTuning-m-J5oo4j/lib/python3.12/site-packages/joblib/externals/loky/backend/reduction.py", line 208, in dump
#     _LokyPickler(file, reducers=reducers, protocol=protocol).dump(obj)
#   File "/home/nadia/.local/share/virtualenvs/HyperparameterTuning-m-J5oo4j/lib/python3.12/site-packages/joblib/externals/cloudpickle/cloudpickle.py", line 1245, in dump
#     return super().dump(obj)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/nadia/.local/share/virtualenvs/HyperparameterTuning-m-J5oo4j/lib/python3.12/site-packages/joblib/_memmapping_reducer.py", line 451, in __call__
#     for dumped_filename in dump(a, filename):
#                            ^^^^^^^^^^^^^^^^^
#   File "/home/nadia/.local/share/virtualenvs/HyperparameterTuning-m-J5oo4j/lib/python3.12/site-packages/joblib/numpy_pickle.py", line 553, in dump
#     NumpyPickler(f, protocol=protocol).dump(value)
#   File "/usr/lib/python3.12/pickle.py", line 481, in dump
#     self.save(obj)
#   File "/home/nadia/.local/share/virtualenvs/HyperparameterTuning-m-J5oo4j/lib/python3.12/site-packages/joblib/numpy_pickle.py", line 352, in save
#     wrapper.write_array(obj, self)
#   File "/home/nadia/.local/share/virtualenvs/HyperparameterTuning-m-J5oo4j/lib/python3.12/site-packages/joblib/numpy_pickle.py", line 134, in write_array
#     pickler.file_handle.write(chunk.tobytes('C'))
# OSError: [Errno 28] No space left on device
# """
#
# The above exception was the direct cause of the following exception:
#
# PicklingError                             Traceback (most recent call last)
# Cell In[5], line 16
#      14 # Inisialisasi GridSearchCV
#      15 grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)
# ---> 16 grid_search.fit(X_train, y_train)
#      18 # Output hasil terbaik
#      19 print(f"Best parameters (Grid Search): {grid_search.best_params_}")
#
# File ~/.local/share/virtualenvs/HyperparameterTuning-m-J5oo4j/lib/python3.12/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/share/virtualenvs/HyperparameterTuning-m-J5oo4j/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1019, in BaseSearchCV.fit(self, X, y, **params)
#    1013     results = self._format_results(
#    1014         all_candidate_params, n_splits, all_out, all_more_results
#    1015     )
#    1017     return results
# -> 1019 self._run_search(evaluate_candidates)
#    1021 # multimetric is determined here because in the case of a callable
#    1022 # self.scoring the return type is only known after calling
#    1023 first_test_score = all_out[0]["test_scores"]
#
# File ~/.local/share/virtualenvs/HyperparameterTuning-m-J5oo4j/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1573, in GridSearchCV._run_search(self, evaluate_candidates)
#    1571 def _run_search(self, evaluate_candidates):
#    1572     """Search all candidates in param_grid"""
# -> 1573     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/.local/share/virtualenvs/HyperparameterTuning-m-J5oo4j/lib/python3.12/site-packages/sklearn/model_selection/_search.py:965, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     957 if self.verbose > 0:
#     958     print(
#     959         "Fitting {0} folds for each of {1} candidates,"
#     960         " totalling {2} fits".format(
#     961             n_splits, n_candidates, n_candidates * n_splits
#     962         )
#     963     )
# --> 965 out = parallel(
#     966     delayed(_fit_and_score)(
#     967         clone(base_estimator),
#     968         X,
#     969         y,
#     970         train=train,
#     971         test=test,
#     972         parameters=parameters,
#     973         split_progress=(split_idx, n_splits),
#     974         candidate_progress=(cand_idx, n_candidates),
#     975         **fit_and_score_kwargs,
#     976     )
#     977     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     978         enumerate(candidate_params),
#     979         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     980     )
#     981 )
#     983 if len(out) < 1:
#     984     raise ValueError(
#     985         "No fits were performed. "
#     986         "Was the CV iterator empty? "
#     987         "Were there no candidates?"
#     988     )
#
# File ~/.local/share/virtualenvs/HyperparameterTuning-m-J5oo4j/lib/python3.12/site-packages/sklearn/utils/parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File ~/.local/share/virtualenvs/HyperparameterTuning-m-J5oo4j/lib/python3.12/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File ~/.local/share/virtualenvs/HyperparameterTuning-m-J5oo4j/lib/python3.12/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File ~/.local/share/virtualenvs/HyperparameterTuning-m-J5oo4j/lib/python3.12/site-packages/joblib/parallel.py:1754, in Parallel._retrieve(self)
#    1747 while self._wait_retrieval():
#    1748
#    1749     # If the callback thread of a worker has signaled that its task
#    1750     # triggered an exception, or if the retrieval loop has raised an
#    1751     # exception (e.g. `GeneratorExit`), exit the loop and surface the
#    1752     # worker traceback.
#    1753     if self._aborting:
# -> 1754         self._raise_error_fast()
#    1755         break
#    1757     # If the next job is not ready for retrieval yet, we just wait for
#    1758     # async callbacks to progress.
#
# File ~/.local/share/virtualenvs/HyperparameterTuning-m-J5oo4j/lib/python3.12/site-packages/joblib/parallel.py:1789, in Parallel._raise_error_fast(self)
#    1785 # If this error job exists, immediately raise the error by
#    1786 # calling get_result. This job might not exists if abort has been
#    1787 # called directly or if the generator is gc'ed.
#    1788 if error_job is not None:
# -> 1789     error_job.get_result(self.timeout)
#
# File ~/.local/share/virtualenvs/HyperparameterTuning-m-J5oo4j/lib/python3.12/site-packages/joblib/parallel.py:745, in BatchCompletionCallBack.get_result(self, timeout)
#     739 backend = self.parallel._backend
#     741 if backend.supports_retrieve_callback:
#     742     # We assume that the result has already been retrieved by the
#     743     # callback thread, and is stored internally. It's just waiting to
#     744     # be returned.
# --> 745     return self._return_or_raise()
#     747 # For other backends, the main thread needs to run the retrieval step.
#     748 try:
#
# File ~/.local/share/virtualenvs/HyperparameterTuning-m-J5oo4j/lib/python3.12/site-packages/joblib/parallel.py:763, in BatchCompletionCallBack._return_or_raise(self)
#     761 try:
#     762     if self.status == TASK_ERROR:
# --> 763         raise self._result
#     764     return self._result
#     765 finally:
#
# PicklingError: Could not pickle the task to send it to the workers.

# %%
from skopt import BayesSearchCV
import time

start_time = time.time()  # Mencatat waktu mulai
 
# Definisikan ruang pencarian untuk Bayesian Optimization
param_space = {
    'n_estimators': (100, 500),
    'max_depth': (10, 50),
    'min_samples_split': (2, 10),
    'min_samples_leaf': (1, 4),
    'bootstrap': [True, False]
}
 
# Inisialisasi BayesSearchCV
bayes_search = BayesSearchCV(estimator=rf, search_spaces=param_space, n_iter=32, cv=3, n_jobs=1, verbose=2, random_state=42)
bayes_search.fit(X_train, y_train)
 
# Output hasil terbaik
print(f"Best parameters (Bayesian Optimization): {bayes_search.best_params_}")
best_rf_bayes = bayes_search.best_estimator_
 
# Evaluasi performa model setelah Random Search
y_pred_bayes = best_rf_bayes.predict(X_test)
bayes_mse = mean_squared_error(y_test, y_pred_bayes)
print(f"MSE after Grid Search: {bayes_mse:.2f}")
end_time = time.time()  # Mencatat waktu selesai
execution_time = end_time - start_time  # Menghitung selisih waktu
print(f"Waktu eksekusi: {execution_time:.4f} detik")
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=39, min_samples_leaf=4, min_samples_split=5, n_estimators=368; total time=  23.5s
# [CV] END bootstrap=True, max_depth=39, min_samples_leaf=4, min_samples_split=5, n_estimators=368; total time=  23.0s
# [CV] END bootstrap=True, max_depth=39, min_samples_leaf=4, min_samples_split=5, n_estimators=368; total time=  23.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=2, min_samples_split=10, n_estimators=446; total time=  46.5s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=2, min_samples_split=10, n_estimators=446; total time=  44.6s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=2, min_samples_split=10, n_estimators=446; total time=  44.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=47, min_samples_leaf=1, min_samples_split=5, n_estimators=175; total time=  13.4s
# [CV] END bootstrap=True, max_depth=47, min_samples_leaf=1, min_samples_split=5, n_estimators=175; total time=  13.2s
# [CV] END bootstrap=True, max_depth=47, min_samples_leaf=1, min_samples_split=5, n_estimators=175; total time=  13.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=False, max_depth=17, min_samples_leaf=3, min_samples_split=8, n_estimators=309; total time=  31.1s
# [CV] END bootstrap=False, max_depth=17, min_samples_leaf=3, min_samples_split=8, n_estimators=309; total time=  30.1s
# [CV] END bootstrap=False, max_depth=17, min_samples_leaf=3, min_samples_split=8, n_estimators=309; total time=  29.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=False, max_depth=28, min_samples_leaf=3, min_samples_split=8, n_estimators=462; total time=  47.4s
# [CV] END bootstrap=False, max_depth=28, min_samples_leaf=3, min_samples_split=8, n_estimators=462; total time=  45.7s
# [CV] END bootstrap=False, max_depth=28, min_samples_leaf=3, min_samples_split=8, n_estimators=462; total time=  45.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=False, max_depth=48, min_samples_leaf=1, min_samples_split=4, n_estimators=420; total time=  50.9s
# [CV] END bootstrap=False, max_depth=48, min_samples_leaf=1, min_samples_split=4, n_estimators=420; total time=  48.2s
# [CV] END bootstrap=False, max_depth=48, min_samples_leaf=1, min_samples_split=4, n_estimators=420; total time=  48.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=False, max_depth=41, min_samples_leaf=2, min_samples_split=9, n_estimators=337; total time=  35.6s
# [CV] END bootstrap=False, max_depth=41, min_samples_leaf=2, min_samples_split=9, n_estimators=337; total time=  33.9s
# [CV] END bootstrap=False, max_depth=41, min_samples_leaf=2, min_samples_split=9, n_estimators=337; total time=  34.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=False, max_depth=47, min_samples_leaf=2, min_samples_split=9, n_estimators=230; total time=  24.3s
# [CV] END bootstrap=False, max_depth=47, min_samples_leaf=2, min_samples_split=9, n_estimators=230; total time=  23.1s
# [CV] END bootstrap=False, max_depth=47, min_samples_leaf=2, min_samples_split=9, n_estimators=230; total time=  23.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=False, max_depth=38, min_samples_leaf=4, min_samples_split=5, n_estimators=252; total time=  25.1s
# [CV] END bootstrap=False, max_depth=38, min_samples_leaf=4, min_samples_split=5, n_estimators=252; total time=  24.1s
# [CV] END bootstrap=False, max_depth=38, min_samples_leaf=4, min_samples_split=5, n_estimators=252; total time=  24.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=43, min_samples_leaf=3, min_samples_split=4, n_estimators=331; total time=  22.2s
# [CV] END bootstrap=True, max_depth=43, min_samples_leaf=3, min_samples_split=4, n_estimators=331; total time=  21.9s
# [CV] END bootstrap=True, max_depth=43, min_samples_leaf=3, min_samples_split=4, n_estimators=331; total time=  22.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  26.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  26.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  26.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  34.7s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  49.4s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  36.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   6.8s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   6.8s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   6.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=  38.8s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=  37.0s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=  38.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  10.5s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   7.9s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   8.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=3, min_samples_split=10, n_estimators=239; total time=  14.7s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=3, min_samples_split=10, n_estimators=239; total time=  17.8s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=3, min_samples_split=10, n_estimators=239; total time=  12.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=346; total time=  29.8s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=346; total time=  30.8s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=346; total time=  34.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=4, min_samples_split=2, n_estimators=113; total time=   7.1s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=4, min_samples_split=2, n_estimators=113; total time=   7.6s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=4, min_samples_split=2, n_estimators=113; total time=   6.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=  44.5s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=  42.8s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=  45.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  44.3s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  42.8s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  39.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   8.4s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   8.4s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   8.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=33, min_samples_leaf=1, min_samples_split=10, n_estimators=459; total time=  37.9s
# [CV] END bootstrap=True, max_depth=33, min_samples_leaf=1, min_samples_split=10, n_estimators=459; total time=  40.2s
# [CV] END bootstrap=True, max_depth=33, min_samples_leaf=1, min_samples_split=10, n_estimators=459; total time=  39.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=40, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  54.0s
# [CV] END bootstrap=True, max_depth=40, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  45.3s
# [CV] END bootstrap=True, max_depth=40, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  45.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=28, min_samples_leaf=2, min_samples_split=2, n_estimators=117; total time=   8.9s
# [CV] END bootstrap=True, max_depth=28, min_samples_leaf=2, min_samples_split=2, n_estimators=117; total time=   8.7s
# [CV] END bootstrap=True, max_depth=28, min_samples_leaf=2, min_samples_split=2, n_estimators=117; total time=   8.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=48, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  43.8s
# [CV] END bootstrap=True, max_depth=48, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  43.5s
# [CV] END bootstrap=True, max_depth=48, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  43.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=22, min_samples_leaf=4, min_samples_split=10, n_estimators=496; total time=  32.1s
# [CV] END bootstrap=True, max_depth=22, min_samples_leaf=4, min_samples_split=10, n_estimators=496; total time=  31.7s
# [CV] END bootstrap=True, max_depth=22, min_samples_leaf=4, min_samples_split=10, n_estimators=496; total time=  31.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=26, min_samples_leaf=4, min_samples_split=2, n_estimators=495; total time=  32.4s
# [CV] END bootstrap=True, max_depth=26, min_samples_leaf=4, min_samples_split=2, n_estimators=495; total time=  32.4s
# [CV] END bootstrap=True, max_depth=26, min_samples_leaf=4, min_samples_split=2, n_estimators=495; total time=  32.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=34, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  37.6s
# [CV] END bootstrap=True, max_depth=34, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  37.4s
# [CV] END bootstrap=True, max_depth=34, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  37.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=34, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  43.6s
# [CV] END bootstrap=True, max_depth=34, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  43.1s
# [CV] END bootstrap=True, max_depth=34, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  43.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=33, min_samples_leaf=3, min_samples_split=10, n_estimators=113; total time=   7.5s
# [CV] END bootstrap=True, max_depth=33, min_samples_leaf=3, min_samples_split=10, n_estimators=113; total time=   7.4s
# [CV] END bootstrap=True, max_depth=33, min_samples_leaf=3, min_samples_split=10, n_estimators=113; total time=   7.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=33, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=  37.5s
# [CV] END bootstrap=True, max_depth=33, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=  37.2s
# [CV] END bootstrap=True, max_depth=33, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=  37.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=22, min_samples_leaf=1, min_samples_split=10, n_estimators=104; total time=   7.6s
# [CV] END bootstrap=True, max_depth=22, min_samples_leaf=1, min_samples_split=10, n_estimators=104; total time=   7.5s
# [CV] END bootstrap=True, max_depth=22, min_samples_leaf=1, min_samples_split=10, n_estimators=104; total time=   7.5s
# Best parameters (Bayesian Optimization): OrderedDict({'bootstrap': True, 'max_depth': 48, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500})
# MSE after Grid Search: 0.25
# Waktu eksekusi: 2843.4092 detik
