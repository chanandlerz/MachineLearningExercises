# %% [markdown]
# # Studi Kasus Hyperparameter Tuning

# %% [markdown]
# ## Latihan Regresi

# %% [markdown]
# ### Import libraries

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import mean_squared_error
from skopt import BayesSearchCV
import time
import numpy as np

# %% [markdown]
# ### Dataset fetching

# %%
X, y = fetch_california_housing(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

print("Shape of training data: ", X_train.shape)
print("Shape of test data: ", X_test.shape)
# a = y_train 
# print(a)
# Out:
# Shape of training data:  (14448, 8)
# Shape of test data:  (6192, 8)

# %% [markdown]
# ### Model training

# %%
rf = RandomForestRegressor(random_state=42)
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
initial_mse = mean_squared_error(y_test, y_pred)
print(f"Initial MSE on test set (without tuning): {initial_mse:.2f}")
# Out:
# Initial MSE on test set (without tuning): 0.26

# %% [markdown]
# ### Tuning

# %% [markdown]
# #### Grid Search

# %%
start_time = time.time()

param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth' : [10, 20, 30],
    'min_samples_split' : [2, 5, 10],
    'min_samples_leaf' : [1, 2, 4],
    'bootstrap' : [True, False]
}

grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, n_jobs=1, verbose=2)

grid_search.fit(X_train, y_train)

print(f"Best parameters (Grid Search): {grid_search.best_params_}")
best_rf_grid = grid_search.best_estimator_


y_pred_grid = best_rf_grid.predict(X_test)
grid_search_mse = mean_squared_error(y_test, y_pred_grid)
print(f"MSE after Grid Search: {grid_search_mse:.2f}")

end_time = time.time()
execution_time = end_time - start_time
print(f"Waktu eksekusi: {execution_time:.4f} detik")
# Out:
# Fitting 3 folds for each of 162 candidates, totalling 486 fits
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   5.7s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   5.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   5.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  12.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  10.9s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  10.8s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  16.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  16.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  17.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   5.4s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   5.4s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   5.4s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  10.8s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  10.8s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  10.9s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  16.8s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  16.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  16.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   5.4s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  11.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  11.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  10.7s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  16.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  16.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  16.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   6.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   5.4s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   5.4s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  10.8s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  10.9s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  10.7s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  16.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  17.6s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  16.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  10.7s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  11.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  11.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  16.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  16.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  16.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   5.9s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   6.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  10.8s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  10.6s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  10.6s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  16.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  16.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  16.4s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   5.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   5.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  10.6s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  10.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  10.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  16.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  15.6s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  15.9s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   5.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   5.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  11.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  11.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  10.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  15.8s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  15.7s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  16.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   5.9s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  10.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  10.4s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  10.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  16.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  16.8s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  15.6s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   8.6s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   8.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   8.5s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  19.1s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  17.1s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  17.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  25.7s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  27.1s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  25.5s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   7.9s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   7.8s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   8.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  16.2s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  15.6s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  15.6s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  24.6s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  23.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  23.2s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   7.3s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   7.8s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   7.9s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  14.5s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  14.5s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  14.5s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  23.1s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  21.7s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  21.7s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   7.5s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   7.5s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   8.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  15.2s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  15.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  15.8s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  23.9s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  22.6s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  22.5s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   7.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   7.3s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   8.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  15.1s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  14.7s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  14.9s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  22.5s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  22.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  22.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   7.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   6.9s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   7.1s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  14.6s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  13.7s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  13.8s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  21.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  22.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  20.9s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   6.6s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   6.6s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   6.5s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  13.6s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  13.6s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  13.1s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  19.6s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  19.8s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  20.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   7.5s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   6.6s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   6.6s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  13.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  13.6s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  14.2s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  20.1s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  19.5s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  20.8s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   7.2s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   6.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   6.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  13.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  12.8s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  12.9s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  21.2s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  18.8s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  19.7s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   8.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   9.4s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   9.5s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  17.7s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  17.6s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  17.5s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  28.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  27.4s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  27.8s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   7.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   7.8s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   8.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  15.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  15.8s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  16.5s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  23.8s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  24.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  24.5s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   7.4s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   7.3s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   7.3s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  14.8s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  14.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  15.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  22.1s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  21.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  23.1s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   7.4s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   7.3s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   7.3s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  14.5s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  14.4s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  14.8s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  21.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  22.5s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  22.4s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   7.2s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   7.1s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   7.2s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  14.6s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  14.3s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  14.7s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  21.7s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  21.6s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  21.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   6.8s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   6.7s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   6.8s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  13.4s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  13.4s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  13.4s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  20.7s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  20.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  20.1s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   6.4s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   6.4s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   6.8s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  12.7s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  12.6s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  12.6s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  19.2s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  19.6s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  19.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   6.4s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   6.3s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   6.4s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  13.3s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  12.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  12.6s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  19.1s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  18.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  19.3s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   6.3s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   6.3s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   6.2s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  12.5s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  12.4s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  12.7s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  18.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  18.7s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  18.7s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   7.9s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   7.8s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   7.6s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  15.4s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  15.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  15.3s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  23.6s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  22.5s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  22.7s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   7.9s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   7.9s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   7.6s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  15.1s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  15.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  15.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  23.6s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  22.6s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  22.7s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   7.8s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   7.8s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   7.5s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  15.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  14.9s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  15.1s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  22.9s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  22.4s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  22.4s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   7.6s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   7.8s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   7.5s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  15.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  15.3s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  15.1s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  23.2s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  22.5s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  22.6s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   7.8s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   7.8s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   7.6s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  15.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  14.9s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  15.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  23.2s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  22.4s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  22.6s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   7.6s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   7.7s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   7.6s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  15.1s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  14.9s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  15.2s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  23.7s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  22.4s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  22.5s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   7.7s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   7.5s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   7.4s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  15.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  14.8s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  14.8s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  22.8s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  22.2s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  22.3s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   7.6s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   7.6s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   7.4s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  15.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  14.8s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  14.8s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  23.3s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  22.5s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  22.5s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   7.9s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   7.7s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   7.5s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  15.1s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  14.9s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  15.1s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  23.4s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  22.4s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  22.8s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  13.3s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  12.2s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  12.1s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  25.1s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  25.1s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  24.4s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  37.7s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  36.6s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  37.3s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  11.6s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  11.2s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  11.3s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  23.3s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  22.8s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  22.8s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  35.4s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  34.1s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  34.5s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  11.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  10.6s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  10.6s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  22.3s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  21.3s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  21.2s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  33.6s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  31.7s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  32.5s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  11.2s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  10.8s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  10.9s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  22.5s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  22.2s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  22.1s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  34.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  32.6s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  33.1s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  11.4s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  10.8s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  10.9s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  22.1s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  21.8s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  21.5s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  33.1s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  33.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  32.4s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  11.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  10.2s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  10.2s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  21.1s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  20.3s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  20.7s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  31.7s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  30.8s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  30.7s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  10.2s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   9.8s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   9.8s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  20.1s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  19.3s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  19.4s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  30.5s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  29.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  29.5s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  10.1s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   9.7s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   9.7s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  20.4s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  19.4s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  19.5s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  30.8s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  29.3s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  29.3s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  10.4s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   9.8s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   9.5s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  20.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  19.1s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  19.3s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  29.9s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  28.9s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  29.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  13.1s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  12.6s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  12.9s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  26.1s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  25.2s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  25.8s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  39.2s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  38.2s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  38.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  12.3s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  11.7s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  11.5s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  23.9s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  26.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  24.8s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  38.9s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  37.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  38.4s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  11.8s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  11.3s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  11.5s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  23.9s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  23.6s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  22.9s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  36.3s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  34.3s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  35.9s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.6s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  11.7s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  11.7s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  26.1s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  23.5s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  23.6s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  38.3s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  35.3s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  37.6s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  12.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  11.5s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  11.6s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  25.4s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  23.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  23.3s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  39.4s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  35.7s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  42.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  11.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  10.3s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  11.1s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  21.5s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  20.3s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  20.7s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  32.4s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  30.7s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  31.3s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  10.2s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   9.8s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   9.7s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  21.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  19.4s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  19.3s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  30.9s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  29.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  29.9s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  10.4s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   9.8s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   9.7s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  20.3s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  19.8s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  19.4s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  30.6s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  29.4s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  29.2s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   9.9s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   9.7s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   9.7s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  20.1s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  19.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  19.5s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  30.6s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  28.7s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  29.2s
# /home/nadia/.local/share/virtualenvs/HyperparameterTuning-m-J5oo4j/lib/python3.12/site-packages/numpy/ma/core.py:2881: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best parameters (Grid Search): {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# MSE after Grid Search: 0.25
# Waktu eksekusi: 8083.5414 detik

# %% [markdown]
# Best parameters (Grid Search): {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# MSE after Grid Search: 0.25
# Waktu eksekusi: 8083.5414 detik

# %% [markdown]
# #### Randomized Search

# %%
start_time = time.time()

param_dist = {
    'n_estimators': np.arange(100, 500, 100),
    'max_depth': [None] + list(np.arange(10, 50, 10)),
    'min_samples_split': np.arange(2,11,2),
    'min_samples_leaf': np.arange(1,5),
    'bootstrap': [True, False]
}

random_search = RandomizedSearchCV(estimator=rf, param_distributions=param_dist, n_iter=5, cv=3, n_jobs=-1, verbose=2, random_state=42)
random_search.fit(X_train, y_train)

print(f"Best parameters (Random Search): {random_search.best_params_}")

best_rf_random = random_search.best_estimator_

y_pred_random = best_rf_random.predict(X_test)
random_search_mse = mean_squared_error(y_test, y_pred_random)
print(f"MSE after Random Search: {random_search_mse:.2f}")

end_time = time.time()
execution_time = end_time - start_time
print(f"Waktu eksekusi: {execution_time:.4f} detik")
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  22.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  23.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  23.7s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=6, n_estimators=300; total time=  43.8s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=2, min_samples_split=8, n_estimators=400; total time= 1.4min
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=6, n_estimators=300; total time=  39.4s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=2, min_samples_split=8, n_estimators=400; total time= 1.4min
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=2, min_samples_split=8, n_estimators=400; total time= 1.5min
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=6, n_estimators=300; total time=  37.6s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=300; total time=  23.7s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=300; total time=  29.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=300; total time=  30.6s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=6, n_estimators=400; total time=  40.4s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=6, n_estimators=400; total time=  37.7s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=6, n_estimators=400; total time=  33.6s
# /home/nadia/.local/share/virtualenvs/HyperparameterTuning-m-J5oo4j/lib/python3.12/site-packages/numpy/ma/core.py:2881: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best parameters (Random Search): {'n_estimators': np.int64(300), 'min_samples_split': np.int64(6), 'min_samples_leaf': np.int64(2), 'max_depth': np.int64(30), 'bootstrap': True}
# MSE after Random Search: 0.25
# Waktu eksekusi: 209.5697 detik

# %% [markdown]
# #### Bayesian Optimization

# %%
start_time = time.time()

param_space = {
    'n_estimators': (100, 500),
    'max_depth': (10, 50),
    'min_samples_split': (2,10),
    'min_samples_leaf': (1,4),
    'bootstrap': [True, False]
}

bayes_search = BayesSearchCV(estimator=rf, search_spaces=param_space, n_iter=32, cv=3, n_jobs=1, verbose=2, random_state=42)
bayes_search.fit(X_train, y_train)

print(f"Best parameters (Bayesian Optimization): {bayes_search.best_params_}")
best_rf_bayes = bayes_search.best_estimator_

y_pred_bayes = best_rf_bayes.predict(X_test)
bayes_mse = mean_squared_error(y_test, y_pred_bayes)
print(f"MSE after Bayesian Optimization: {bayes_mse:.2f}")

end_time = time.time()
execution_time = end_time - start_time
print(f"Waktu eksekusi: {execution_time:.4f} detik")
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=39, min_samples_leaf=4, min_samples_split=5, n_estimators=368; total time=  24.0s
# [CV] END bootstrap=True, max_depth=39, min_samples_leaf=4, min_samples_split=5, n_estimators=368; total time=  23.7s
# [CV] END bootstrap=True, max_depth=39, min_samples_leaf=4, min_samples_split=5, n_estimators=368; total time=  23.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=2, min_samples_split=10, n_estimators=446; total time=  48.9s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=2, min_samples_split=10, n_estimators=446; total time=  47.0s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=2, min_samples_split=10, n_estimators=446; total time=  47.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=47, min_samples_leaf=1, min_samples_split=5, n_estimators=175; total time=  13.8s
# [CV] END bootstrap=True, max_depth=47, min_samples_leaf=1, min_samples_split=5, n_estimators=175; total time=  13.7s
# [CV] END bootstrap=True, max_depth=47, min_samples_leaf=1, min_samples_split=5, n_estimators=175; total time=  13.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=False, max_depth=17, min_samples_leaf=3, min_samples_split=8, n_estimators=309; total time=  32.7s
# [CV] END bootstrap=False, max_depth=17, min_samples_leaf=3, min_samples_split=8, n_estimators=309; total time=  31.5s
# [CV] END bootstrap=False, max_depth=17, min_samples_leaf=3, min_samples_split=8, n_estimators=309; total time=  31.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=False, max_depth=28, min_samples_leaf=3, min_samples_split=8, n_estimators=462; total time=  50.4s
# [CV] END bootstrap=False, max_depth=28, min_samples_leaf=3, min_samples_split=8, n_estimators=462; total time=  48.3s
# [CV] END bootstrap=False, max_depth=28, min_samples_leaf=3, min_samples_split=8, n_estimators=462; total time=  48.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=False, max_depth=48, min_samples_leaf=1, min_samples_split=4, n_estimators=420; total time=  53.4s
# [CV] END bootstrap=False, max_depth=48, min_samples_leaf=1, min_samples_split=4, n_estimators=420; total time=  51.6s
# [CV] END bootstrap=False, max_depth=48, min_samples_leaf=1, min_samples_split=4, n_estimators=420; total time=  52.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=False, max_depth=41, min_samples_leaf=2, min_samples_split=9, n_estimators=337; total time=  37.8s
# [CV] END bootstrap=False, max_depth=41, min_samples_leaf=2, min_samples_split=9, n_estimators=337; total time=  36.1s
# [CV] END bootstrap=False, max_depth=41, min_samples_leaf=2, min_samples_split=9, n_estimators=337; total time=  36.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=False, max_depth=47, min_samples_leaf=2, min_samples_split=9, n_estimators=230; total time=  25.8s
# [CV] END bootstrap=False, max_depth=47, min_samples_leaf=2, min_samples_split=9, n_estimators=230; total time=  24.6s
# [CV] END bootstrap=False, max_depth=47, min_samples_leaf=2, min_samples_split=9, n_estimators=230; total time=  24.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=False, max_depth=38, min_samples_leaf=4, min_samples_split=5, n_estimators=252; total time=  26.5s
# [CV] END bootstrap=False, max_depth=38, min_samples_leaf=4, min_samples_split=5, n_estimators=252; total time=  25.3s
# [CV] END bootstrap=False, max_depth=38, min_samples_leaf=4, min_samples_split=5, n_estimators=252; total time=  25.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=43, min_samples_leaf=3, min_samples_split=4, n_estimators=331; total time=  22.8s
# [CV] END bootstrap=True, max_depth=43, min_samples_leaf=3, min_samples_split=4, n_estimators=331; total time=  22.7s
# [CV] END bootstrap=True, max_depth=43, min_samples_leaf=3, min_samples_split=4, n_estimators=331; total time=  23.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  27.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  27.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  27.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  35.2s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  34.6s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  34.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   6.5s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   6.5s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   6.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=  32.9s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=  32.7s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=  32.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   7.4s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   7.3s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   7.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=3, min_samples_split=10, n_estimators=239; total time=  12.8s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=3, min_samples_split=10, n_estimators=239; total time=  13.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=3, min_samples_split=10, n_estimators=239; total time=  12.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=346; total time=  30.2s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=346; total time=  29.9s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=346; total time=  29.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=4, min_samples_split=2, n_estimators=113; total time=   6.3s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=4, min_samples_split=2, n_estimators=113; total time=   6.3s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=4, min_samples_split=2, n_estimators=113; total time=   6.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=  40.4s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=  40.0s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=  40.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  37.7s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  37.2s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  37.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   7.5s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   7.4s
# [CV] END bootstrap=True, max_depth=50, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   7.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=33, min_samples_leaf=1, min_samples_split=10, n_estimators=459; total time=  33.7s
# [CV] END bootstrap=True, max_depth=33, min_samples_leaf=1, min_samples_split=10, n_estimators=459; total time=  33.1s
# [CV] END bootstrap=True, max_depth=33, min_samples_leaf=1, min_samples_split=10, n_estimators=459; total time=  33.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=40, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  43.7s
# [CV] END bootstrap=True, max_depth=40, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  43.2s
# [CV] END bootstrap=True, max_depth=40, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  43.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=28, min_samples_leaf=2, min_samples_split=2, n_estimators=117; total time=   8.7s
# [CV] END bootstrap=True, max_depth=28, min_samples_leaf=2, min_samples_split=2, n_estimators=117; total time=   8.7s
# [CV] END bootstrap=True, max_depth=28, min_samples_leaf=2, min_samples_split=2, n_estimators=117; total time=   8.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=48, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  43.5s
# [CV] END bootstrap=True, max_depth=48, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  43.3s
# [CV] END bootstrap=True, max_depth=48, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  43.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=22, min_samples_leaf=4, min_samples_split=10, n_estimators=496; total time=  32.0s
# [CV] END bootstrap=True, max_depth=22, min_samples_leaf=4, min_samples_split=10, n_estimators=496; total time=  31.6s
# [CV] END bootstrap=True, max_depth=22, min_samples_leaf=4, min_samples_split=10, n_estimators=496; total time=  31.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=26, min_samples_leaf=4, min_samples_split=2, n_estimators=495; total time=  32.2s
# [CV] END bootstrap=True, max_depth=26, min_samples_leaf=4, min_samples_split=2, n_estimators=495; total time=  32.2s
# [CV] END bootstrap=True, max_depth=26, min_samples_leaf=4, min_samples_split=2, n_estimators=495; total time=  32.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=34, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  37.4s
# [CV] END bootstrap=True, max_depth=34, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  37.0s
# [CV] END bootstrap=True, max_depth=34, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  37.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=34, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  43.6s
# [CV] END bootstrap=True, max_depth=34, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  43.1s
# [CV] END bootstrap=True, max_depth=34, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  43.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=33, min_samples_leaf=3, min_samples_split=10, n_estimators=113; total time=   7.6s
# [CV] END bootstrap=True, max_depth=33, min_samples_leaf=3, min_samples_split=10, n_estimators=113; total time=   7.5s
# [CV] END bootstrap=True, max_depth=33, min_samples_leaf=3, min_samples_split=10, n_estimators=113; total time=   7.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=33, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=  37.6s
# [CV] END bootstrap=True, max_depth=33, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=  37.2s
# [CV] END bootstrap=True, max_depth=33, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=  37.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END bootstrap=True, max_depth=22, min_samples_leaf=1, min_samples_split=10, n_estimators=104; total time=   7.6s
# [CV] END bootstrap=True, max_depth=22, min_samples_leaf=1, min_samples_split=10, n_estimators=104; total time=   7.5s
# [CV] END bootstrap=True, max_depth=22, min_samples_leaf=1, min_samples_split=10, n_estimators=104; total time=   7.5s
# Best parameters (Bayesian Optimization): OrderedDict({'bootstrap': True, 'max_depth': 48, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500})
# MSE after Bayesian Optimization: 0.25
# Waktu eksekusi: 2778.2622 detik

# %% [markdown]
# ## Latihan Klasifikasi

# %% [markdown]
# ### Data load and Data Preprocessing

# %%
from sklearn.datasets import fetch_openml
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

X, y = fetch_openml(name='credit-g', version=1, return_X_y=True, as_frame=True)
# print(X)
# print(y)
le = LabelEncoder()
y = le.fit_transform(y)

X_encoded = pd.get_dummies(X, drop_first=True)

X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.3, random_state=42)

print("Shape of training data: ", X_train.shape)
print("Shape of testing data: ", X_test.shape)
# Out:
# Shape of training data:  (700, 48)
# Shape of testing data:  (300, 48)

# %% [markdown]
# ### Model training

# %%
rf = RandomForestClassifier(random_state=42)
rf.fit(X_train, y_train)

initial_score = rf.score(X_test, y_test)
print(f"Initial accuracy on test set (without tuning): {initial_score:.2f}")
# Out:
# Initial accuracy on test set (without tuning): 0.76

# %% [markdown]
# ### Parameter Tuning

# %% [markdown]
# #### Grid Search

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'criterion': ['gini', 'entropy']
}

grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, n_jobs=1, verbose=2)
grid_search.fit(X_train, y_train)

print(f"Best parameters (Grid Search): {grid_search.best_params_}")
best_rf_grid = grid_search.best_estimator_

grid_search_score = best_rf_grid.score(X_test, y_test)
print(f"Accuracy after Grid Search: {grid_search_score:.2f}")
# Out:
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
# [CV] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=300; total time=   0.6s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=300; total time=   0.5s
# Best parameters (Grid Search): {'criterion': 'gini', 'max_depth': 30, 'min_samples_split': 5, 'n_estimators': 200}
# Accuracy after Grid Search: 0.76

# %% [markdown]
# #### Random Search

# %%
param_dist = {
    'n_estimators': np.linspace(100, 500, 5, dtype=int),
    'max_depth': np.linspace(10,50,5, dtype=int),
    'min_samples_split': [2, 5, 10],
    'criterion': ['gini', 'entropy']
}

random_search = RandomizedSearchCV(estimator=rf, param_distributions=param_dist, n_iter=20, cv=3, n_jobs=1, verbose=2, random_state=42)
random_search.fit(X_train, y_train)

print(f"Best parameters (Random Search): {random_search.best_params_}")
best_rf_random = random_search.best_estimator_
 
random_search_score = best_rf_random.score(X_test, y_test)
print(f"Accuracy after Random Search: {random_search_score:.2f}")
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV] END criterion=gini, max_depth=50, min_samples_split=10, n_estimators=400; total time=   0.7s
# [CV] END criterion=gini, max_depth=50, min_samples_split=10, n_estimators=400; total time=   0.7s
# [CV] END criterion=gini, max_depth=50, min_samples_split=10, n_estimators=400; total time=   0.7s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=400; total time=   0.7s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=400; total time=   0.7s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=400; total time=   0.7s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=400; total time=   0.7s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=400; total time=   0.7s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=400; total time=   0.9s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=400; total time=   0.7s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=400; total time=   0.7s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=400; total time=   0.7s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=50, min_samples_split=2, n_estimators=500; total time=   0.9s
# [CV] END criterion=gini, max_depth=50, min_samples_split=2, n_estimators=500; total time=   0.9s
# [CV] END criterion=gini, max_depth=50, min_samples_split=2, n_estimators=500; total time=   0.9s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=50, min_samples_split=5, n_estimators=400; total time=   0.7s
# [CV] END criterion=gini, max_depth=50, min_samples_split=5, n_estimators=400; total time=   0.7s
# [CV] END criterion=gini, max_depth=50, min_samples_split=5, n_estimators=400; total time=   0.7s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=500; total time=   0.8s
# [CV] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=500; total time=   0.8s
# [CV] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=500; total time=   0.8s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=500; total time=   0.8s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=500; total time=   0.8s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=500; total time=   0.8s
# [CV] END criterion=gini, max_depth=40, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=40, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=40, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10, n_estimators=500; total time=   0.8s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10, n_estimators=500; total time=   0.9s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10, n_estimators=500; total time=   0.9s
# [CV] END criterion=gini, max_depth=50, min_samples_split=5, n_estimators=500; total time=   1.2s
# [CV] END criterion=gini, max_depth=50, min_samples_split=5, n_estimators=500; total time=   1.2s
# [CV] END criterion=gini, max_depth=50, min_samples_split=5, n_estimators=500; total time=   1.0s
# [CV] END criterion=gini, max_depth=40, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=40, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=40, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=40, min_samples_split=10, n_estimators=300; total time=   0.6s
# [CV] END criterion=entropy, max_depth=40, min_samples_split=10, n_estimators=300; total time=   0.6s
# [CV] END criterion=entropy, max_depth=40, min_samples_split=10, n_estimators=300; total time=   0.6s
# Best parameters (Random Search): {'n_estimators': np.int64(200), 'min_samples_split': 5, 'max_depth': np.int64(30), 'criterion': 'gini'}
# Accuracy after Random Search: 0.76

# %%
param_space = {
    'n_estimators': (100, 500),
    'max_depth': (10, 50),
    'min_samples_split': (2, 10),
    'criterion': ['gini', 'entropy']
}

bayes_search = BayesSearchCV(estimator=rf, search_spaces=param_space, n_iter=32, cv=3, n_jobs=1, verbose=2, random_state=42)
bayes_search.fit(X_train, y_train)

print(f"Best parameters (Bayesian Optimization): {bayes_search.best_params_}")
best_rf_bayes = bayes_search.best_estimator_
 
bayes_search_score = best_rf_bayes.score(X_test, y_test)
print(f"Accuracy after Bayesian Optimization: {bayes_search_score:.2f}")
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=gini, max_depth=39, min_samples_split=9, n_estimators=226; total time=   0.4s
# [CV] END criterion=gini, max_depth=39, min_samples_split=9, n_estimators=226; total time=   0.5s
# [CV] END criterion=gini, max_depth=39, min_samples_split=9, n_estimators=226; total time=   0.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=45, min_samples_split=4, n_estimators=480; total time=   0.9s
# [CV] END criterion=entropy, max_depth=45, min_samples_split=4, n_estimators=480; total time=   1.0s
# [CV] END criterion=entropy, max_depth=45, min_samples_split=4, n_estimators=480; total time=   0.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=gini, max_depth=47, min_samples_split=3, n_estimators=273; total time=   0.5s
# [CV] END criterion=gini, max_depth=47, min_samples_split=3, n_estimators=273; total time=   0.5s
# [CV] END criterion=gini, max_depth=47, min_samples_split=3, n_estimators=273; total time=   0.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=17, min_samples_split=7, n_estimators=421; total time=   0.8s
# [CV] END criterion=entropy, max_depth=17, min_samples_split=7, n_estimators=421; total time=   0.8s
# [CV] END criterion=entropy, max_depth=17, min_samples_split=7, n_estimators=421; total time=   0.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=28, min_samples_split=6, n_estimators=386; total time=   0.8s
# [CV] END criterion=entropy, max_depth=28, min_samples_split=6, n_estimators=386; total time=   0.7s
# [CV] END criterion=entropy, max_depth=28, min_samples_split=6, n_estimators=386; total time=   0.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=48, min_samples_split=3, n_estimators=175; total time=   0.4s
# [CV] END criterion=entropy, max_depth=48, min_samples_split=3, n_estimators=175; total time=   0.4s
# [CV] END criterion=entropy, max_depth=48, min_samples_split=3, n_estimators=175; total time=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=41, min_samples_split=5, n_estimators=450; total time=   0.8s
# [CV] END criterion=entropy, max_depth=41, min_samples_split=5, n_estimators=450; total time=   0.8s
# [CV] END criterion=entropy, max_depth=41, min_samples_split=5, n_estimators=450; total time=   0.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=47, min_samples_split=6, n_estimators=435; total time=   0.8s
# [CV] END criterion=entropy, max_depth=47, min_samples_split=6, n_estimators=435; total time=   0.9s
# [CV] END criterion=entropy, max_depth=47, min_samples_split=6, n_estimators=435; total time=   0.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=38, min_samples_split=9, n_estimators=266; total time=   0.5s
# [CV] END criterion=entropy, max_depth=38, min_samples_split=9, n_estimators=266; total time=   0.5s
# [CV] END criterion=entropy, max_depth=38, min_samples_split=9, n_estimators=266; total time=   0.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=gini, max_depth=43, min_samples_split=8, n_estimators=202; total time=   0.4s
# [CV] END criterion=gini, max_depth=43, min_samples_split=8, n_estimators=202; total time=   0.4s
# [CV] END criterion=gini, max_depth=43, min_samples_split=8, n_estimators=202; total time=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=47, min_samples_split=2, n_estimators=210; total time=   0.4s
# [CV] END criterion=entropy, max_depth=47, min_samples_split=2, n_estimators=210; total time=   0.4s
# [CV] END criterion=entropy, max_depth=47, min_samples_split=2, n_estimators=210; total time=   0.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=gini, max_depth=48, min_samples_split=10, n_estimators=474; total time=   0.9s
# [CV] END criterion=gini, max_depth=48, min_samples_split=10, n_estimators=474; total time=   0.8s
# [CV] END criterion=gini, max_depth=48, min_samples_split=10, n_estimators=474; total time=   0.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=49, min_samples_split=2, n_estimators=126; total time=   0.3s
# [CV] END criterion=entropy, max_depth=49, min_samples_split=2, n_estimators=126; total time=   0.2s
# [CV] END criterion=entropy, max_depth=49, min_samples_split=2, n_estimators=126; total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=454; total time=   0.8s
# [CV] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=454; total time=   0.8s
# [CV] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=454; total time=   0.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=46, min_samples_split=10, n_estimators=499; total time=   0.9s
# [CV] END criterion=entropy, max_depth=46, min_samples_split=10, n_estimators=499; total time=   0.8s
# [CV] END criterion=entropy, max_depth=46, min_samples_split=10, n_estimators=499; total time=   0.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=gini, max_depth=16, min_samples_split=3, n_estimators=107; total time=   0.2s
# [CV] END criterion=gini, max_depth=16, min_samples_split=3, n_estimators=107; total time=   0.2s
# [CV] END criterion=gini, max_depth=16, min_samples_split=3, n_estimators=107; total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=18, min_samples_split=8, n_estimators=442; total time=   0.7s
# [CV] END criterion=entropy, max_depth=18, min_samples_split=8, n_estimators=442; total time=   0.8s
# [CV] END criterion=entropy, max_depth=18, min_samples_split=8, n_estimators=442; total time=   0.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=37, min_samples_split=9, n_estimators=258; total time=   0.4s
# [CV] END criterion=entropy, max_depth=37, min_samples_split=9, n_estimators=258; total time=   0.4s
# [CV] END criterion=entropy, max_depth=37, min_samples_split=9, n_estimators=258; total time=   0.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=369; total time=   0.6s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=369; total time=   0.6s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=369; total time=   0.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=gini, max_depth=10, min_samples_split=9, n_estimators=145; total time=   0.3s
# [CV] END criterion=gini, max_depth=10, min_samples_split=9, n_estimators=145; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, min_samples_split=9, n_estimators=145; total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=10, min_samples_split=3, n_estimators=114; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=3, n_estimators=114; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=3, n_estimators=114; total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=25, min_samples_split=5, n_estimators=412; total time=   0.8s
# [CV] END criterion=entropy, max_depth=25, min_samples_split=5, n_estimators=412; total time=   0.7s
# [CV] END criterion=entropy, max_depth=25, min_samples_split=5, n_estimators=412; total time=   0.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=gini, max_depth=50, min_samples_split=5, n_estimators=419; total time=   0.7s
# [CV] END criterion=gini, max_depth=50, min_samples_split=5, n_estimators=419; total time=   0.7s
# [CV] END criterion=gini, max_depth=50, min_samples_split=5, n_estimators=419; total time=   0.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=gini, max_depth=50, min_samples_split=10, n_estimators=444; total time=   0.8s
# [CV] END criterion=gini, max_depth=50, min_samples_split=10, n_estimators=444; total time=   0.7s
# [CV] END criterion=gini, max_depth=50, min_samples_split=10, n_estimators=444; total time=   0.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=gini, max_depth=50, min_samples_split=6, n_estimators=107; total time=   0.2s
# [CV] END criterion=gini, max_depth=50, min_samples_split=6, n_estimators=107; total time=   0.2s
# [CV] END criterion=gini, max_depth=50, min_samples_split=6, n_estimators=107; total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=10, min_samples_split=4, n_estimators=153; total time=   0.3s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=4, n_estimators=153; total time=   0.3s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=4, n_estimators=153; total time=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=gini, max_depth=12, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=12, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=12, min_samples_split=10, n_estimators=100; total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=gini, max_depth=11, min_samples_split=5, n_estimators=500; total time=   0.8s
# [CV] END criterion=gini, max_depth=11, min_samples_split=5, n_estimators=500; total time=   0.9s
# [CV] END criterion=gini, max_depth=11, min_samples_split=5, n_estimators=500; total time=   0.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=gini, max_depth=50, min_samples_split=4, n_estimators=395; total time=   0.7s
# [CV] END criterion=gini, max_depth=50, min_samples_split=4, n_estimators=395; total time=   0.7s
# [CV] END criterion=gini, max_depth=50, min_samples_split=4, n_estimators=395; total time=   0.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=gini, max_depth=50, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=50, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=50, min_samples_split=10, n_estimators=100; total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=123; total time=   0.3s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=123; total time=   0.2s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=123; total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=14, min_samples_split=2, n_estimators=500; total time=   0.9s
# [CV] END criterion=entropy, max_depth=14, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_split=2, n_estimators=500; total time=   1.1s
# Best parameters (Bayesian Optimization): OrderedDict({'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 5, 'n_estimators': 369})
# Accuracy after Bayesian Optimization: 0.75
